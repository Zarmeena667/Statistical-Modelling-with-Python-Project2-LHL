# %% [markdown]
# Build a regression model.

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model, datasets
import statsmodels.api as sm

# %%
df= pd.read_csv('finalfinal_df.csv')
df
# Out:
#      Unnamed: 0                       Name  ReviewCount  Rating  \
# 0             0               AFRU Gallery          3.0     4.5
# 1             1           Adams and Ollman          1.0     5.0
# 2             2     Alberta Street Gallery         13.0     5.0
# 3             3             Antler Gallery          7.0     4.5
# 4             4  Artistic Portland Gallery         18.0     5.0
# ..          ...                        ...          ...     ...
# 273         273            SE Alder at 6th          NaN     4.0
# 274         274            SE 8th at Alder          NaN     4.0
# 275         275      Cleveland High School          NaN     4.0
# 276         276       NE 37th at NE Shaver          NaN     4.0
# 277         277       NE 29th Ave (U of O)          NaN     4.0
#
#      location.zip_code  empty_slots  free_bikes   Latitude   Longitude  \
# 0              97214.0          NaN         NaN  45.519840 -122.660138
# ...

# %%
X= df['Distance']
Y= df['Rating']

# %%
X = sm.add_constant(X)
lin_reg = sm.OLS(Y,X)

# %%
model = lin_reg.fit()
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Rating   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     2.236
# Date:                Sun, 19 Nov 2023   Prob (F-statistic):              0.136
# Time:                        06:41:37   Log-Likelihood:                -99.287
# No. Observations:                 278   AIC:                             202.6
# Df Residuals:                     276   BIC:                             209.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.8780      0.128     30.347      0.000       3.626       4.130
# ...

# %% [markdown]
# Provide model output and an interpretation of the results.

# %% [markdown]
# The merged dataframe has a high number of null values and imputed values (Ratings and Distance). It is evident from the supremely low R-squared value of 0.008 that this is not the best fit model.
# A p-value of less than 0.05 is considered to be statistically significant. This regression output shows a p-value of 0, which means that the distance does not impact the rating.

# %% [markdown]
# # Stretch

# %% [markdown]
# How can you turn the regression model into a classification model?
